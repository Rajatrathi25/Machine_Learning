# %%
import bs4
import urllib.request as req

# %%
httpresponse=req.urlopen('https://www.flipkart.com/')

# %%
httpresponse

# %%
bs4.BeautifulSoup(httpresponse)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.46f631.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
newresponse=req.urlopen('https://www.flipkart.com/audio-video/pr?sid=0pm&offer=nb:mp:05e9ef6621&fm=neo%2Fmerchandising&iid=M_55e482ac-3ce2-4d81-81ee-ed9f6151ee82_2.OV3TV244UTKP&otracker=hp_omu_Deals%2Bof%2Bthe%2BDay_1_2.dealCard.OMU_OV3TV244UTKP_2&otracker1=hp_omu_PINNED_neo%2Fmerchandising_Deals%2Bof%2Bthe%2BDay_NA_dealCard_cc_1_NA_view-all_2&cid=OV3TV244UTKP')

# %%
newresponse

# %%
newout=bs4.BeautifulSoup(newresponse)

# %%
newout
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.46f631.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
a=newout.find('a',class_='_2cLu-l')

# %%
a.text
# Out:
# 'boAt Rockerz 510 Super Extra Bass Bluetooth Headset wit...'

# %%
alltitle=newout.find_all('a',class_='_2cLu-l')

# %%
alltitle
# Out:
# [<a class="_2cLu-l" href="/boat-rockerz-510-super-extra-bass-bluetooth-headset-mic/p/itmf3vhgvymtjqhx?pid=ACCEZB5QGQBDWVWD&amp;lid=LSTACCEZB5QGQBDWVWDH4MY6X&amp;marketplace=FLIPKART&amp;srno=b_1_1&amp;otracker=hp_omu_Deals%2Bof%2Bthe%2BDay_1_2.dealCard.OMU_OV3TV244UTKP_2&amp;otracker1=hp_omu_PINNED_neo%2Fmerchandising_Deals%2Bof%2Bthe%2BDay_NA_dealCard_cc_1_NA_view-all_2&amp;fm=organic&amp;iid=9dfadfdb-e200-48e8-a607-3c83d1ada097.ACCEZB5QGQBDWVWD.SEARCH" rel="noopener noreferrer" target="_blank" title="boAt Rockerz 510 Super Extra Bass Bluetooth Headset with Mic">boAt Rockerz 510 Super Extra Bass Bluetooth Headset wit...</a>,
# ...

# %%
for i in alltitle:
    print(i.text)
# Out:
# boAt Rockerz 510 Super Extra Bass Bluetooth Headset wit...
# boAt Rockerz 400 Super Extra Bass Bluetooth Headset wit...
# boAt Rockerz 400 Kings XI Punjab Edition Bluetooth Head...
# boAt BassHeads 100 Wired Headset with Mic
# Sony EX14AP Wired Headset with Mic
# SoundLogic Voice Assistant Wireless Stereo Headphone Bl...
# boAt stone 260 5 W Portable Bluetooth  Speaker
# boAt stone 260 5 W Portable Bluetooth  Speaker
# Intex 2622 Portable Bluetooth Laptop/Desktop Speaker
# Boult Audio AirBass Monopod Bluetooth Headset with Mic
# F&D E200 3 W Portable Laptop/Desktop Speaker
# Ant Audio Wave 506 Wired Headset with Mic
# Motorola Pulse 2 Wired Headset with Mic
# JBL T110BT Bluetooth Headset with Mic
# Sony EX155 Wired Headset with Mic
# JBL T110BT Bluetooth Headset with Mic
# JVC XS-XN226 8 w Bluetooth  Speaker
# SoundLogic PLAY Voice Assistant Sport Earbuds Bluetooth...
# KRISONS ETERNITY 5.1BT with Bluetooth,USB,AUX-IN&FM Rad...
# PTron Boom 2 4D Earphone Wired Headset with Mic
# ...

# %%
price=newout.find('a',class_='_1Vfi6u')

# %%
price.text
# Out:
# '₹1,849₹3,49047% off'

# %%
priceall=newout.find_all('a',class_='_1Vfi6u')

# %%
for i in priceall:
    print(i.text)
# Out:
# ₹1,849₹3,49047% off
# ₹1,399₹2,99053% off
# ₹1,899₹3,99052% off
# ₹379₹99962% off
# ₹599₹1,29053% off
# ₹1,599₹2,99946% off
# ₹1,449₹2,49041% off
# ₹1,449₹2,49041% off
# ₹1,899₹2,69929% off
# ₹799₹2,66570% off
# ₹899₹9909% off
# ₹549₹69921% off
# ₹799₹1,49946% off
# ₹1,999₹2,49920% off
# ₹999₹1,29022% off
# ₹2,189₹2,49912% off
# ₹1,499₹3,99962% off
# ₹1,049₹1,99947% off
# ₹2,149₹4,99056% off
# ₹648₹1,70061% off
# ₹1,299₹4,99974% off
# ₹1,299₹2,85054% off
# ₹999₹1,69941% off
# ₹749₹99925% off
# ₹1,899₹3,29042% off
# ₹728₹1,50051% off
# ₹1,998₹2,99033% off
# ₹2,148₹4,99957% off
# ₹697₹1,49953% off
# ₹249₹39937% off
# ₹1,798₹2,99940% off
# ₹1,999₹4,99059% off
# ₹1,899₹2,49924% off
# ₹1,498₹2,99950% off
# ₹998₹2,29956% off
# ₹1,098₹1,49926% off
# ₹934₹1,99953% off
# ₹197₹39950% off
# ₹2,148₹4,00046% off
# ₹1,997₹3,99049% off

# %%
for i in range(len(alltitle)):
    print(alltitle[i].text,priceall[i].text)
# Out:
# boAt Rockerz 510 Super Extra Bass Bluetooth Headset wit... ₹1,849₹3,49047% off
# boAt Rockerz 400 Super Extra Bass Bluetooth Headset wit... ₹1,399₹2,99053% off
# boAt Rockerz 400 Kings XI Punjab Edition Bluetooth Head... ₹1,899₹3,99052% off
# boAt BassHeads 100 Wired Headset with Mic ₹379₹99962% off
# Sony EX14AP Wired Headset with Mic ₹599₹1,29053% off
# SoundLogic Voice Assistant Wireless Stereo Headphone Bl... ₹1,599₹2,99946% off
# boAt stone 260 5 W Portable Bluetooth  Speaker ₹1,449₹2,49041% off
# boAt stone 260 5 W Portable Bluetooth  Speaker ₹1,449₹2,49041% off
# Intex 2622 Portable Bluetooth Laptop/Desktop Speaker ₹1,899₹2,69929% off
# Boult Audio AirBass Monopod Bluetooth Headset with Mic ₹799₹2,66570% off
# F&D E200 3 W Portable Laptop/Desktop Speaker ₹899₹9909% off
# Ant Audio Wave 506 Wired Headset with Mic ₹549₹69921% off
# Motorola Pulse 2 Wired Headset with Mic ₹799₹1,49946% off
# JBL T110BT Bluetooth Headset with Mic ₹1,999₹2,49920% off
# ...
