# %%
import bs4
import urllib.request as req

# %%
httpresponse=req.urlopen('https://www.flipkart.com/boat-rockerz-510-super-extra-bass-bluetooth-headset-mic/p/itmf3vhgvymtjqhx?pid=ACCEZB5QGQBDWVWD&lid=LSTACCEZB5QGQBDWVWDH4MY6X&marketplace=FLIPKART&srno=b_1_1&otracker=hp_omu_Deals%2Bof%2Bthe%2BDay_1_2.dealCard.OMU_OV3TV244UTKP_2&otracker1=hp_omu_PINNED_neo%2Fmerchandising_Deals%2Bof%2Bthe%2BDay_NA_dealCard_cc_1_NA_view-all_2&fm=neo%2Fmerchandising&iid=02bfecb6-20d1-4555-94ed-76ed04617e4d.ACCEZB5QGQBDWVWD.SEARCH&ppt=browse&ppn=browse&ssid=uobhzqixog0000001561353964835')

# %%
page=bs4.BeautifulSoup(httpresponse)

# %%
page
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.46f631.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
name=page.find('span',class_='_35KyD6')

# %%
name1=name.text

# %%
price=page.find('div',class_='_3iZgFn')

# %%
price1=price.text

# %%
price1
# Out:
# '₹1,999₹3,49042% off'

# %%
hig=page.find('div',class_='bhgxx2 col-6-12')

# %%
high1=hig.text

# %%
rate=page.find('span',class_='_38sUEc')

# %%
rating=rate.text

# %%
review=page.find('div',class_='_3nrCtb')

# %%
review1=review.text

# %%
print('name is\n',name1)
print('price is\n',price1)
print('HIGHLIGHT is\n',high1)
print('Rating is\n',rating)
print('Review is\n',review1)
# Out:
# name is
#  boAt Rockerz 510 Super Extra Bass Bluetooth Headset with Mic  (Red, Black, Over the Ear)
# price is
#  ₹1,999₹3,49042% off
# HIGHLIGHT is
#  HighlightsWith Mic:YesBluetooth version: 4.1Wireless range: 10 mBattery life: 8 hrs | Charging time: 2 hrsExtra bass: Add extra thump to your musicUsing simple touch controls answer phone calls, change music tracks and control volumeLightweight and comfortable ear tips which is available in 3 sizes provides comfortable musical experience for longer listening
# Rating is
#  26,621 Ratings & 4,219 Reviews
# Review is
# ...

# %%
review=page.find('div',class_='col _39LH-M')

# %%
print(review)
# Out:
# <div class="col _39LH-M"><div class="_1B7BXc"><div class="_3unCI7">Ratings &amp; Reviews</div><div class="_36nEq1"><button class="_2AkmmA _2XOAEz" type="submit"><span>Rate Product</span></button></div></div><div class="row _1Ahy2t _2aFisS"><div class="ebepc-"><div class="row"><div class="col-4-12"><div class="col"><div class="row"><div class="col-12-12 _11EBw0"><div class="_1i0wk8">4.4</div><div class="_2txNna">★</div></div></div><div class="row _2yc1Qo"><div class="col-12-12"><span>26,621 Ratings &amp;</span></div></div><div class="row _2yc1Qo"><div class="col-12-12"><span>4,219 Reviews</span></div></div></div></div><div class="col-8-12 _1S74qC TxMRTO"><div class="_1n1j36 DrZOea uD3lY9"><ul><li class="_58ZIbs"><div class="_1atKHO col col-2-12"><span class="_3ApwOG">5</span><span class="_2bhdZh">★</span></div><div class="col col-7-12"><div class="_1WmLa3"><span class="_1Yym6V euq4L_" style="width:100%"></span></div></div><div class="col col-3-12"><div class="CamDho"> 16,586</div></di
# ...

# %%
link=review.find_all('a')[-1]['href']

# %%
print(link)
# Out:
# /boat-rockerz-510-super-extra-bass-bluetooth-headset-mic/product-reviews/itmf3vhgvymtjqhx?pid=ACCEZB5QGQBDWVWD

# %%
newresponse=req.urlopen('https://www.flipkart.com'+link)

# %%
print(newresponse)

# %%
page1=bs4.BeautifulSoup(newresponse)

# %%
page1
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.46f631.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
head=page1.find_all('p',class_='_2xg6Ul')

# %%
head
# Out:
# [<p class="_2xg6Ul">Must buy!</p>,
#  <p class="_2xg6Ul">Brilliant</p>,
#  <p class="_2xg6Ul">Great product</p>,
#  <p class="_2xg6Ul">Worth every penny</p>,
#  <p class="_2xg6Ul">Good quality product</p>,
#  <p class="_2xg6Ul">Really Nice</p>,
#  <p class="_2xg6Ul">Mind-blowing purchase</p>,
#  <p class="_2xg6Ul">Nice product</p>,
#  <p class="_2xg6Ul">Fabulous!</p>,
#  <p class="_2xg6Ul">Really Nice</p>]

# %%
for i in head:
    print(i.text)
# Out:
# Must buy!
# Brilliant
# Great product
# Worth every penny
# Good quality product
# Really Nice
# Mind-blowing purchase
# Nice product
# Fabulous!
# Really Nice
