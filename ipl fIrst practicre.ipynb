# %%
import pandas as pd

# %%
matches=pd.read_csv('matches.csv')

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
#no. of matches played by the team 
pd.value_counts(matches['season'],sort=False)
# Out:
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# 2018    60
# 2019    60
# Name: season, dtype: int64

# %%
#no. of time a team has won 
pd.value_counts(matches['winner'])
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
# top 5 man of the match 
pd.value_counts(matches['player_of_match']).head()
# Out:
# CH Gayle          21
# AB de Villiers    20
# MS Dhoni          17
# RG Sharma         17
# DA Warner         17
# Name: player_of_match, dtype: int64

# %%
pd.value_counts(matches['player_of_match']).tail()
# Out:
# SA Asnodkar      1
# Kuldeep Yadav    1
# RJ Harris        1
# KV Sharma        1
# J Botha          1
# Name: player_of_match, dtype: int64

# %%
#find the winner of the ipl seasons 
final_matches=matches.drop_duplicates('season',keep='last')

# %%
final_matches
# Out:
#         id  season          city        date                team1  \
# 58      59    2017     Hyderabad  2017-05-21       Mumbai Indians
# 116    117    2008        Mumbai  2008-06-01  Chennai Super Kings
# 173    174    2009  Johannesburg  2009-05-24      Deccan Chargers
# 233    234    2010        Mumbai  2010-04-25  Chennai Super Kings
# 306    307    2011       Chennai  2011-05-28  Chennai Super Kings
# 380    381    2012       Chennai  2012-05-27  Chennai Super Kings
# 456    457    2013       Kolkata  2013-05-26       Mumbai Indians
# 516    517    2014     Bangalore  2014-06-01      Kings XI Punjab
# 575    576    2015       Kolkata  2015-05-24       Mumbai Indians
# 635    636    2016     Bangalore  2016-05-29  Sunrisers Hyderabad
# 695   7953    2018        Mumbai    27/05/18  Sunrisers Hyderabad
# 755  11415    2019     Hyderabad    12/05/19       Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
pd.value_counts(final_matches['winner'])
# Out:
# Mumbai Indians           4
# Chennai Super Kings      3
# Kolkata Knight Riders    2
# Rajasthan Royals         1
# Sunrisers Hyderabad      1
# Deccan Chargers          1
# Name: winner, dtype: int64

# %%
tempdf=final_matches[['season','winner']]

# %%
tempdf=tempdf.reset_index()
#run it two times to remove match number bcz table has two index

# %%
tempdf[['season','winner']]
# Out:
#     season                 winner
# 0     2017         Mumbai Indians
# 1     2008       Rajasthan Royals
# 2     2009        Deccan Chargers
# 3     2010    Chennai Super Kings
# 4     2011    Chennai Super Kings
# 5     2012  Kolkata Knight Riders
# 6     2013         Mumbai Indians
# 7     2014  Kolkata Knight Riders
# 8     2015         Mumbai Indians
# 9     2016    Sunrisers Hyderabad
# 10    2018    Chennai Super Kings
# 11    2019         Mumbai Indians

# %%
pd.value_counts(matches['win_by_runs'])
# Out:
# 0      419
# 14      13
# 4       11
# 10      11
# 1       10
# 13       9
# 23       9
# 15       9
# 7        9
# 9        9
# 22       9
# 37       8
# 24       8
# 12       8
# 19       8
# 2        7
# 11       7
# 25       7
# 6        7
# 17       7
# 18       7
# 27       6
# 16       6
# 20       6
# 34       6
# 5        6
# 41       5
# 8        5
# 45       5
# 38       5
#       ...
# 77       1
# 93       1
# 102      1
# 87       1
# 105      1
# 111      1
# 118      1
# 130      1
# 138      1
# 140      1
# 42       1
# 74       1
# 76       1
# 75       1
# 144      1
# 47       1
# 50       1
# 36       1
# 51       1
# 53       1
# 57       1
# 59       1
# 60       1
# 61       1
# 62       1
# 64       1
# 66       1
# 67       1
# 72       1
# 146      1
# Name: win_by_runs, Length: 89, dtype: int64

# %%
temp_df=matches[matches['win_by_runs']!=0]

# %%
pd.value_counts(temp_df['win_by_runs'])
# Out:
# 14     13
# 10     11
# 4      11
# 1      10
# 13      9
# 23      9
# 7       9
# 9       9
# 22      9
# 15      9
# 37      8
# 24      8
# 12      8
# 19      8
# 2       7
# 11      7
# 25      7
# 6       7
# 17      7
# 18      7
# 27      6
# 16      6
# 20      6
# 34      6
# 5       6
# 41      5
# 45      5
# 8       5
# 38      5
# 31      5
#        ..
# 77      1
# 93      1
# 102     1
# 87      1
# 105     1
# 111     1
# 118     1
# 130     1
# 138     1
# 140     1
# 42      1
# 74      1
# 76      1
# 75      1
# 144     1
# 47      1
# 50      1
# 51      1
# 36      1
# 53      1
# 57      1
# 59      1
# 60      1
# 61      1
# 62      1
# 64      1
# 66      1
# 67      1
# 72      1
# 146     1
# Name: win_by_runs, Length: 88, dtype: int64

# %%
#find how many matches a team won in a season 
seasons=pd.unique(matches['season'])

# %%
winner_in_each_season=[]
for season in seasons:
    matches_in_a_season=matches[matches['season']==season]
    winner_in_each_season.append(pd.value_counts(matches_in_a_season['winner']))

# %%
for i in range(len(winner_in_each_season)):
    print('season in ',seasons[i])
    print(winner_in_each_season[i])
    print('\n')
# Out:
# season in  2017
# Mumbai Indians                 12
# Rising Pune Supergiant         10
# Kolkata Knight Riders           9
# Sunrisers Hyderabad             8
# Kings XI Punjab                 7
# Delhi Daredevils                6
# Gujarat Lions                   4
# Royal Challengers Bangalore     3
# Name: winner, dtype: int64
#
#
# season in  2008
# Rajasthan Royals               13
# Kings XI Punjab                10
# Chennai Super Kings             9
# Delhi Daredevils                7
# Mumbai Indians                  7
# Kolkata Knight Riders           6
# Royal Challengers Bangalore     4
# Deccan Chargers                 2
# Name: winner, dtype: int64
#
#
# season in  2009
# Delhi Daredevils               10
# Deccan Chargers                 9
# Royal Challengers Bangalore     9
# Chennai Super Kings             8
# Kings XI Punjab                 7
# Rajasthan Royals                6
# Mumbai Indians                  5
# Kolkata Knight Riders           3
# ...

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
new = matches[(matches['winner'] == 'Chennai Super Kings')&(matches['win_by_runs']>50)]

# %%
new[['team1','team2','win_by_runs']]
# Out:
#                    team1                        team2  win_by_runs
# 121  Chennai Super Kings  Royal Challengers Bangalore           92
# 143  Chennai Super Kings              Deccan Chargers           78
# 181  Chennai Super Kings        Kolkata Knight Riders           55
# 284  Chennai Super Kings             Rajasthan Royals           63
# 306  Chennai Super Kings  Royal Challengers Bangalore           58
# 312  Chennai Super Kings              Deccan Chargers           74
# 379  Chennai Super Kings             Delhi Daredevils           86
# 403  Chennai Super Kings             Delhi Daredevils           86
# 434  Chennai Super Kings          Sunrisers Hyderabad           77
# 464  Chennai Super Kings             Delhi Daredevils           93
# 541  Chennai Super Kings              Kings XI Punjab           97
# 652  Chennai Super Kings             Rajasthan Royals           64
# 745  Chennai Super Kings               Delhi Capitals           80

# %%
delivery=pd.read_csv('deliveries.csv')

# %%
delivery
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 5              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 6              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 7              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 8              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 9              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 10             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...

# %%
caught=delivery[delivery['dismissal_kind']=='caught']

# %%
caught
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 165            1       2  Royal Challengers Bangalore
# 206            1       2  Royal Challengers Bangalore
# 211            1       2  Royal Challengers Bangalore
# 230            1       2  Royal Challengers Bangalore
# 234            1       2  Royal Challengers Bangalore
# 242            1       2  Royal Challengers Bangalore
# 330            2       1               Mumbai Indians
# 343            2       1               Mumbai Indians
# 361            2       1               Mumbai Indians
# 392            2       2       Rising Pune Supergiant
# 434            2       2       Rising Pune Supergiant
# 467            2       2       Rising Pune Supergiant
# 514            3       1                Gujarat Lions
# ...

# %%
pd.value_counts(caught['fielder']).head()
# Out:
# KD Karthik        109
# SK Raina           99
# MS Dhoni           98
# AB de Villiers     93
# RV Uthappa         84
# Name: fielder, dtype: int64

# %%
bowler1=delivery[['dismissal_kind','bowler']]
bowler=bowler1.dropna()

# %%
bowler
# Out:
#                dismissal_kind           bowler
# 11                     caught      A Choudhary
# 64                     caught        STR Binny
# 94                     caught        YS Chahal
# 116                    bowled         TS Mills
# 160                    bowled      Rashid Khan
# 165                    caught         DJ Hooda
# 199                   run out     MC Henriques
# 206                    caught      Rashid Khan
# 211                    caught     Bipul Sharma
# 230                    caught          B Kumar
# 234                    caught          A Nehra
# 235                    bowled          A Nehra
# 242                    caught          B Kumar
# 247                   run out      BCJ Cutting
# 274                    bowled      Imran Tahir
# 287                    bowled      Imran Tahir
# 289                       lbw      Imran Tahir
# 316         caught and bowled         R Bhatia
# 330                    caught         R Bhatia
# ...

# %%
#pd.value_counts(team2['bowler']).head()
bowler=bowler[bowler['dismissal_kind'] != 'run out']
#bowler=bowler[bowler['dismissal_kind'] != 'hit wicket']
bowler=bowler[bowler['dismissal_kind'] != 'retired hurt']
bowler=bowler[bowler['dismissal_kind'] != 'obstructing the field ']

# %%
pd.value_counts(bowler['bowler']).head()
# Out:
# SL Malinga         170
# A Mishra           156
# Harbhajan Singh    150
# PP Chawla          149
# DJ Bravo           147
# Name: bowler, dtype: int64

# %%
delivery_type=pd.unique(delivery['dismissal_kind'])

# %%
delivery_type
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
DKlist=[]
for i in range(len(delivery_type)-1):
    DKlist.append(delivery_type[i+1])

# %%
for i in DKlist:
    print("\n For "+i+" type of dismissal-")
    print(pd.value_counts(delivery[delivery['dismissal_kind']==i]['batsman']).head())
# Out:
#  For caught type of dismissal-
# SK Raina      112
# RV Uthappa    108
# RG Sharma     103
# V Kohli        95
# KD Karthik     85
# Name: batsman, dtype: int64
#
#  For bowled type of dismissal-
# SR Watson    32
# V Kohli      30
# S Dhawan     28
# G Gambhir    27
# MK Pandey    24
# Name: batsman, dtype: int64
#
#  For run out type of dismissal-
# MS Dhoni      21
# RG Sharma     17
# KD Karthik    16
# V Kohli       15
# G Gambhir     15
# Name: batsman, dtype: int64
#
#  For lbw type of dismissal-
# BB McCullum    16
# RV Uthappa     13
# PA Patel       12
# DR Smith       12
# AM Rahane      11
# Name: batsman, dtype: int64
#
#  For caught and bowled type of dismissal-
# SK Raina     7
# RG Sharma    6
# RA Jadeja    5
# R Dravid     5
# AM Rahane    5
# Name: batsman, dtype: int64
#
#  For stumped type of dismissal-
# SK Raina          8
# AT Rayudu         7
# RV Uthappa        7
# PA Patel          6
# AB de Villiers    6
# Name: batsman, dtype: int64
#
# ...

# %%
toss_decision=pd.value_counts(matches['toss_decision'])
toss_decision
#labels=['field','bat']
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %%
# toss decision is a series and can be treated like an array 
toss_decision.keys()[0]
# Out:
# 'field'

# %%
labels=[]
for key in toss_decision.keys():
    labels.append(key)
labels
# Out:
# ['field', 'bat']

# %%
import matplotlib.pyplot as plot

# %%
plot.pie(toss_decision,labels=labels, autopct='%.2f%%',startangle=90,explode=(.5,2))
# %.2f% only this gives percentage and .2f give that the value after decimal will be upto two numbers . 
# last % is to print the percentage sign 
# start angle is used to shift the pie chart with some angle 
# explode will seperate both of the charts
# Out:
# ([<matplotlib.patches.Wedge at 0x12f33d2b668>,
# ...
#  [Text(-1.5012211897857526, -0.5534753285723314, 'field'),
#   Text(2.9086160552098956, 1.0723584491088918, 'bat')],
#  [Text(-1.0320895679777047, -0.3805142883934778, '61.24%'),
#   Text(2.4394844334018475, 0.8993974089300382, '38.76%')])

# %%
delivery.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
dismissal_kind=pd.value_counts(delivery['dismissal_kind'])

# %%
dismissal_kind
# Out:
# caught                   5348
# bowled                   1581
# run out                   852
# lbw                       540
# stumped                   278
# caught and bowled         211
# retired hurt               12
# hit wicket                 10
# obstructing the field       2
# Name: dismissal_kind, dtype: int64

# %%
x=delivery[delivery['dismissal_kind']!='obstructing the field']
dismissal_kind=pd.value_counts(x['dismissal_kind'],sort=False)

# %%
dismissal_kind = dismissal_kind.sort_index()

# %%
labels=[]
for key in dismissal_kind.keys():
    labels.append(key)
labels
# Out:
# ['bowled',
#  'caught',
#  'caught and bowled',
#  'hit wicket',
#  'lbw',
#  'retired hurt',
#  'run out',
#  'stumped']

# %%
plot.pie(dismissal_kind,radius=3,labels=labels,autopct='%.2f%%',pctdistance=1,startangle=90,
         explode=[0.5,0,0,0,0,0,0,0],counterclock=False)
plot.legend(labels)

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# toss_decision=pd.value_counts(matches['toss_decision'])
# toss_decision
# labels=[]
# for key in toss_decision.keys():
#     #print(key)
#     labels.append(key)
# labels
fielding = matches[matches['toss_decision'] == 'field']

# %%
# winner_by_field=0
# loss_by_field=0
# loss_by_bat=0
# winner_by_bat=0
# toss=matches[['toss_winner','toss_decision','winner']]
# toss=toss.dropna()
# toss
win_by_fielding = fielding[fielding['toss_winner'] == fielding['winner']]
loss_by_fielding = fielding[fielding['toss_winner'] != fielding['winner']]

# %%
# for i in toss.index:
#     #print(i)
#     for key in toss['toss_decision']:
#         if key == labels[0]:
#             if toss['toss_winner'][i]==toss['winner'][i]:
#                 winner_by_field+=1
#             else:
#                 loss_by_field+=1
#         if key == labels[1]:
#             if toss['toss_winner'][i]==toss['winner'][i]:
#                 winner_by_bat+=1
#             else:
#                 loss_by_bat+=1
# print(winner_by_field)
# print(loss_by_field)
# print(winner_by_bat)
# print(loss_by_bat)
batting = matches[matches['toss_decision'] == 'bat']
win_by_batting = batting[batting['toss_winner'] == batting['winner']]
loss_by_batting = batting[batting['toss_winner'] != batting['winner']]

# %%
win_by_batting_count = int(pd.value_counts(win_by_batting['toss_decision']))
#print(win_by_batting_count)
win_by_fielding_count = int(pd.value_counts(win_by_fielding['toss_decision']))
loss_by_batting_count = int(pd.value_counts(loss_by_batting['toss_decision']))
loss_by_fielding_count = int(pd.value_counts(loss_by_fielding['toss_decision']))
# Out:
# 134

# %%
win_loss = {
    'scenario': ['win_by_batting','win_by_fielding','loss_by_batting','loss_by_fielding'],
    'value': [win_by_batting_count,win_by_fielding_count,loss_by_batting_count,loss_by_fielding_count]
}

# %%
plot.pie(win_loss['value'],labels = win_loss['scenario'], autopct = '%.f%%' , startangle= 90,radius=4)
#when we store it the list content is removed
# Out:
# ([<matplotlib.patches.Wedge at 0x12f33c0c908>,
# ...
#  [Text(-2.325439057846214, 3.7352822099867256, 'win_by_batting'),
#   Text(-3.583169806453462, -2.553604146715043, 'win_by_fielding'),
#   Text(3.1112698372208087, -3.11126983722081, 'loss_by_batting'),
#   Text(3.2990371459478, 2.9114178521223297, 'loss_by_fielding')],
#  [Text(-1.2684213042797527, 2.037426659992759, '18%'),
#   Text(-1.9544562580655245, -1.392874989117296, '34%'),
#   Text(1.6970562748477136, -1.6970562748477145, '21%'),
#   Text(1.7994748068806181, 1.5880461011576341, '27%')])

# %%
plot.hist(matches['season'])
# Out:
# (array([115.,  60.,  73.,  74.,  76.,  60.,  59.,  60.,  59., 120.]),
#  array([2008. , 2009.1, 2010.2, 2011.3, 2012.4, 2013.5, 2014.6, 2015.7,
#         2016.8, 2017.9, 2019. ]),
#  <a list of 10 Patch objects>)

# %%
from matplotlib import style

# %%
seasons=pd.unique(matches['season'])
seasons.sort()
plot.bar(seasons,pd.value_counts(matches['season'],sort=False))
#style.use('ggplot')
style.use('fivethirtyeight')

# %%
plot.hist(matches['season'],rwidth=0.9,bins=[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018])
# Out:
# (array([ 58.,  57.,  60.,  73.,  74.,  76.,  60.,  59.,  60., 119.]),
#  array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]),
#  <a list of 10 Patch objects>)

# %%
plot.hist(matches['season'],rwidth=0.9,range=[2008,2018])
# Out:
# (array([ 58.,  57.,  60.,  73.,  74.,  76.,  60.,  59.,  60., 119.]),
#  array([2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015., 2016.,
#         2017., 2018.]),
#  <a list of 10 Patch objects>)
